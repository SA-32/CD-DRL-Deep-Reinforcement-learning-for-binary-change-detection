# %%
# %cd PIXELDRL-MG-Medical-Image-Segmentation-Using-Deep-Reinforcement-Learning
# Out:
# /pfs/data6/home/ka/ka_scc/ka_at8511/Project_ChangeFormer/alpha/PIXELDRL-MG-Medical-Image-Segmentation-Using-Deep-Reinforcement-Learning

# %%
# !python train.py
# Out:
# /opt/amdgpu/share/libdrm/amdgpu.ids: No such file or directory
# Loaded pretrained weights for efficientnet-b0
# Params set by AI: DeviceGroupedConvFwdMultipleABD_Xdl_CShuffle<256, 128, 128, 16, OddC, 32, 32, 2, 2, 1, 1, 4, 1, 1, 1>
# Params set by AI: DeviceGroupedConvFwdMultipleABD_Xdl_CShuffle<64, 64, 64, 16, OddC, 32, 32, 2, 2, 1, 1, 1, 1, 1, 1>
# Params set by AI: DeviceGroupedConvFwdMultipleABD_Xdl_CShuffle_V3<128, 32, 16, 64, OddC, 16, 16, 1, 1, 4, 4, 2, 1, 1, BlkGemmPipelineScheduler: Interwave, BlkGemmPipelineVersion: v1>
# Params set by AI: DeviceGroupedConvFwdMultipleABD_Xdl_CShuffle<64, 64, 64, 16, OddC, 32, 32, 2, 2, 1, 1, 1, 1, 1, 1>
# Params set by AI: DeviceGroupedConvFwdMultipleABD_Xdl_CShuffle<64, 64, 32, 16, OddC, 32, 32, 2, 1, 4, 4, 4, 1, 1, 1>
# Params set by AI: DeviceGroupedConvFwdMultipleABD_Xdl_CShuffle<256, 128, 64, 16, Filter1x1Stride1Pad0, 32, 32, 2, 1, 4, 4, 4, 1, 1, 1>
# ...
